# %%
def get_top_student(df):
    column = (df['중간고사'] >= 90) & (df['기말고사']>=90)
    return df[column]

def make_scatter(df):
    x = df['출결상황']
    y = df['수행평가']
    plt.scatter(x,y)
    plot.show()

# %%
from matplotlib.pyplot as plt

def youngest_average_mean(df):
    youngest = df['학년'].min()
    return round(df[df['학년']==youngest]['기말고사'].mean(), 3)
def midterm_final_corr(df):
    return rount(df['중간고사'].corr(df['기말고사']), 3)
def plot_final_histogram(df):
    plt.figure(figsize=(10,5))
    plt.hist(df['기말고사'], bins=10)
    plt.show()

# %%
from PIL import Image

def get_graduated_count(df):
    return len(df[df['졸업여부'] == 1])
def remove_nan(df):
    df = df.dropna()
    return df
def make_box(df):
    plt.boxplot(df['기말고사'])
    box = show_plot("box")
    return box

# %%
from sklearn.ensemble import RandomForestRegressor

def get_X_y(df):
    X = df.drop(columns=['id','반'], axis=1)
    y = df['기말고사']
    return X,y
def main():
    df_train = pd.read_csv('/data/student.csv')
    df_test = pd.read_csv('/data/submission.csv')

    x_train, y_train = get_X_y(df_train)

    model = RandomForestRegressor(max_depth =3, n_estimators=100)
    model.fit(x_train, y_train)

    pred = model.predict(df_test.drop(columns=['id'], axis=1))

    return model, pred

# %%
from sklearn.linear_model import LinearRegression, Ridge

def get_X_y(df):
    X = df.drop(columns=['기말고사'],axis=1)
    y = df['기말고사']
    reutrn X,y
def main():
    x_train, y_train = get_X_y(df)

    linear_model = LinearRegression()
    ridge_model = Ridge(alpha=0.3)

    linear_model.fit(x_train,y_trian)
    ridge_model.fit(x_train,y_train)

    linear_pred = linear_model.predict(df_test)
    ridge_pred = ridge_model.predict(df_test)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler

def load_data(path):
    return pd.read_csv(path)

def extract_features_labes(df):
    features = df.drop(columns=['index','졸업여부'], axis=1)
    labels = df['졸업여부']
    return features, labels

def extract_features(df):
    features = df.drop(columns=['index'], axis=1)
    return features

def scale_features(train_features, test_features):
    scaler = MinMaxScaler
    train_scaled = scaler.fit_transform(train_features)
    test_scaled = scaler.transform(test_features)
    return train_scaled, test_scaled

def main():
    X_train, y_train = extract_features_labels(train_df)
    X_test = extract_features(test_df)
    X_train_scaled, X_test_scaled = scale_features(X_train, X_test)

    svc_model = SVC()
    svc_model.fit(X_train_sceld,y_train)

    pred = svc_model.predict(X_test_scaled)
    test_df['졸업여부'] = pred
    return svc_model, test_df

# %%
import tensorflow as tf

a = tf.constant(10, dtype = tf.int32)
b = tf.constant(3, dtype = tf.int32)
add = tf.add(a,b)
sub = tf.subtract(a,b)
mul = tf.multiply(a,b)
div = tf.truediv(a,b)

# %%
from sklearn.model_selection import train_test_split

TRAIN_PATH = 'data/train.csv'

def load_csv(path):
    df = pd.read_csv(path)
    return df

def label_encoding(series):
    status_map = {
        'Low':3,
        'Middle':2,
        'High':1
    }
    return series.map(status_map)

def divide_data(df):
    features = df.drop(columns=['price'], axis=1)
    X = df[features]
    y = df['price']
    X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size=0.4)

# %%
def fill_missing_with_mean(df, column):
    df[column] = df[column].fillna(df[column].mean())
    return df

def remove_outliers_iqr(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3-q1
    lower_bound = q1-1.5*iqr
    upper_bound = q3+1.5*iqr
    return df[(df[column]>=lower_bound)*(df[column]<=upper_bound)]

def draw_pie_chart(df, column):
    counts = df[column].value_counts()
    plt.pie(counts, autopct=%1.1f%%)

# %%
from skleanr.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

def preprocessing_data(df):
    df = df.copy()
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col].fillna(df[col].mode()[0], inplace=True)
            df[col] = LabelEncoder().fit_transform(df[col])
        else :
            df[col].fillna(df[col].mean(), inplace=True)
    return df

def smote(X,y):
    smote = SMOTE(random_state=32)
    X_smote, y_smote = smote.fit_resample(X,y)
    return X_smote, y_smote

def rus(X,y):
    rus = RandomUnderSampler(random_state=7)
    X_rus, y_rus = rus.fit_resample(X,y)
    return X_rus, y_rus

# %%
from sklearn.tree import DecisionTreeRegressor

def combine_df(df1, df2):
    df_combined = pd.concat([df1,df2], axis=0, ignore_index=True)
    return df_combined

def get_X_y(df):
    df = df.drop(columns=['측정일자'], axis = 1)
    X = df.drop(columns=['기말고사'], axis = 1)
    y = df['기말고사']
    return X,y

def modeling(X,y, df_test):
    model = DecisionTreeRegressor()
    model.fit(X,y)
    pred = model.predict(df_test)
    return pred

# %%
def split_data(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=32)
    return X_train, X_test, y_train, y_test

def train_decision_Tree(X_train, y_train):
    model = DecisionTreeClassifier(random_state=32)
    model.fit(X_train,y_train)
    return model

def plot_feature_importances(model, feature_names):
    plt.figure(dpi=150)
    importances = model.feature_importances_
    plt.barh(feature_names, importances)

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

def k_means_clus(spamDF):
    kmeans = KMeans(init='random', n_clusters=2, random_State=123)
    kmeans.fit(spamDF.drop(columns=['스팸여부'], axis=1))
    spamDF['cluster'] = kmeans.labels_
    spam_result = spamDF.groupby(['스팸여부','클러스터'])['무료_단어_빈도'].count()

def Visualize(spamDF):
    pca = PCA(n_components=2, random_state=123)
    pca.fit(spamDF.crop(columns=['스팸여부'], axis=1))
    pca_transformed = pca.transform(spamDF.drop(columns=['스팸여부'], axis=1))
    
    spamDF['pca_x'] = pca_transformed[:,0]
    spamDF['pca_y'] = pca_transformed[:,1]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

def encode_labels(df):
    return df['성별'].map({'남':0, '여':1})

def exract_and _scale_features(df):
    X = df.drop(colums=['id','성별'], axis=1)
    scaler = StandardScaler()
    return sclaer.fit_transform(X)

def split_data(X,y):
    return train_test_split(X,y,test_size=0.3,stratify=y, random_state=32)

def train_and_predict(X_train, X_test, y_train, y_test):
    model = KNeighborsClassifier(n_neighbors=10)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    acc = accuract_score(y_test,y_pred)
    return model, acc

# %%
import tensorflow as tf
from tensorflow import keras

def make_model1():
    model1 = tf.keras.models.Sequential([
        tf.keras.layers.Dense(units=120, input_shape=(2,)),
        tf.keras.layers.Dense(units=250, activation='relu'),
        tf.keras.layers.Dense(units=60, activation='relu'),
        tf.keras.layers.Dense(units=12, activation='softmax')
    ])
    return model1

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder

def ready_data():
    df = pd.read_csv('dog_data.csv')
    df = df.dropna()
    X = df[].values
    y = df['breed'].values.reshape(-1,1)
    return X,y

def data_transform(X,y):
    encoder = OneHotEncoder(sparse=False)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    y = encoder.fit_transform(y)

def train_mode(X_train,y_train):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(units=64, input_shape=(4,), activation='relu'),
        tf.keras.layers.Dense(units=32, activation='relu'),
        tf.keras.layers.Dense(units=5, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=5)

# %%
def change_column_name(df):
    df = df.rename(columns = {'출결상황':'출결'})
    return df

def bin_final_score(df):
    def binning(score):
        if pd.isnull(score):
            return score
        elif score < 60:
            return 0
        elif 60<=score<80:
            return 1
        elif 80 <= score:
            return 2
    df['기말고사'] = df['기말고사'].map(binning)
    return df

def encode_grade(df):
    df = pd.get_dummies(df, columns=['기말고사'])
    return df

    pd.get_dummies(df, columns=['기말고사'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, SimpleRNN

def cnn():
    cnn = Sequential([
        Input(shape=(32,32,1)),
        Conv2D(8, kernel_size=(5,5), activation ='relu'),
        Conv2D(16, kernel_size=(3,3), ac)
        Flatten()
        Dense(10, )
    ])

def rnn():
    rnn = Sequential([
        Input(shape=(30,2))
        SimpleRNN(64, activation)
        Dense(5)
    ])
